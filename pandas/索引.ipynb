# %% [markdown]
# ## 3 索引

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 3.1 索引器

# %%
df = pd.read_csv('data/learn_pandas.csv',usecols=['School', 'Grade', 'Name', 'Gender',
                                                  'Weight', 'Transfer'])

# %%
df
# Out:
#                             School      Grade            Name  Gender  Weight  \
# 0    Shanghai Jiao Tong University   Freshman    Gaopeng Yang  Female    46.0
# 1                Peking University   Freshman  Changqiang You    Male    70.0
# 2    Shanghai Jiao Tong University     Senior         Mei Sun    Male    89.0
# 3                 Fudan University  Sophomore    Xiaojuan Sun  Female    41.0
# 4                 Fudan University  Sophomore     Gaojuan You    Male    74.0
# ..                             ...        ...             ...     ...     ...
# 195               Fudan University     Junior    Xiaojuan Sun  Female    46.0
# 196            Tsinghua University     Senior         Li Zhao  Female    50.0
# 197  Shanghai Jiao Tong University     Senior  Chengqiang Chu  Female    45.0
# 198  Shanghai Jiao Tong University     Senior   Chengmei Shen    Male    71.0
# 199            Tsinghua University  Sophomore     Chunpeng Lv    Male    51.0
#
#     Transfer
# 0          N
# ...

# %% [markdown]
# 对列经操作

# %%
df['School'].head()
# Out:
# 0    Shanghai Jiao Tong University
# 1                Peking University
# 2    Shanghai Jiao Tong University
# 3                 Fudan University
# 4                 Fudan University
# Name: School, dtype: object

# %%
df[['School','Grade']]
# Out:
#                             School      Grade
# 0    Shanghai Jiao Tong University   Freshman
# 1                Peking University   Freshman
# 2    Shanghai Jiao Tong University     Senior
# 3                 Fudan University  Sophomore
# 4                 Fudan University  Sophomore
# ..                             ...        ...
# 195               Fudan University     Junior
# 196            Tsinghua University     Senior
# 197  Shanghai Jiao Tong University     Senior
# 198  Shanghai Jiao Tong University     Senior
# 199            Tsinghua University  Sophomore
#
# [200 rows x 2 columns]

# %%
df.Grade.head()
# Out:
# 0     Freshman
# 1     Freshman
# 2       Senior
# 3    Sophomore
# 4    Sophomore
# Name: Grade, dtype: object

# %%
# 序列的行索引
s = pd.Series([1, 2, 3, 4, 5, 6],index=['a', 'b', 'a', 'a', 'a', 'c'])

# %%
# 切片取数需保障索引是唯一的
s['b':'c':2]
# Out:
# b    2
# a    4
# c    6
# dtype: int64

# %%
# series 还可直接以整数为索引，默认从0开始
s[1]
# Out:
# 2

# %%
s[[2,3]]
# Out:
# a    3
# a    4
# dtype: int64

# %%
# 切片
s[1:-1:1]
# Out:
# b    2
# a    3
# a    4
# a    5
# dtype: int64

# %% [markdown]
# 对行进行操作 ：基于元素的loc和基于位置的iloc
# loc[*,*]第一个* 代表行选择，第二个*代表列选择，需对索引列执行loc

# %%
df_demo = df.set_index('Name')
df_demo
# Out:
#                                        School      Grade  Gender  Weight  \
# Name
# Gaopeng Yang    Shanghai Jiao Tong University   Freshman  Female    46.0
# Changqiang You              Peking University   Freshman    Male    70.0
# Mei Sun         Shanghai Jiao Tong University     Senior    Male    89.0
# Xiaojuan Sun                 Fudan University  Sophomore  Female    41.0
# Gaojuan You                  Fudan University  Sophomore    Male    74.0
# ...                                       ...        ...     ...     ...
# Xiaojuan Sun                 Fudan University     Junior  Female    46.0
# Li Zhao                   Tsinghua University     Senior  Female    50.0
# Chengqiang Chu  Shanghai Jiao Tong University     Senior  Female    45.0
# Chengmei Shen   Shanghai Jiao Tong University     Senior    Male    71.0
# Chunpeng Lv               Tsinghua University  Sophomore    Male    51.0
#
#                Transfer
# Name
# Gaopeng Yang          N
# Changqiang You        N
# ...

# %%
# 如果唯一，则为series，如果不唯一则是dataframe
df_demo.loc['Gaopeng Yang']
# Out:
# School      Shanghai Jiao Tong University
# Grade                            Freshman
# Gender                             Female
# Weight                               46.0
# Transfer                                N
# Name: Gaopeng Yang, dtype: object

# %%
df_demo.loc['Qiang Sun']
# Out:
#                                   School      Grade  Gender  Weight Transfer
# Name
# Qiang Sun            Tsinghua University     Junior  Female    53.0        N
# Qiang Sun            Tsinghua University  Sophomore  Female    40.0        N
# Qiang Sun  Shanghai Jiao Tong University     Junior  Female     NaN        N

# %%
# 同时选择行和列
df_demo.loc['Qiang Sun','School']
# Out:
# Name
# Qiang Sun              Tsinghua University
# Qiang Sun              Tsinghua University
# Qiang Sun    Shanghai Jiao Tong University
# Name: School, dtype: object

# %%
df.loc[3]
# Out:
# School      Fudan University
# Grade              Sophomore
# Name            Xiaojuan Sun
# Gender                Female
# Weight                  41.0
# Transfer                   N
# Name: 3, dtype: object

# %%
# 根据条件取数
df_demo.loc[df_demo.Weight>70]
# Out:
#                                          School      Grade Gender  Weight  \
# Name
# Mei Sun           Shanghai Jiao Tong University     Senior   Male    89.0
# Gaojuan You                    Fudan University  Sophomore   Male    74.0
# Xiaopeng Zhou     Shanghai Jiao Tong University   Freshman   Male    74.0
# Xiaofeng Sun                Tsinghua University     Senior   Male    71.0
# Qiang Zheng       Shanghai Jiao Tong University     Senior   Male    87.0
# Gaoli Zhao                    Peking University   Freshman   Male    78.0
# Xiaojuan Qin                  Peking University   Freshman   Male    79.0
# Qiang Han                     Peking University   Freshman   Male    87.0
# Li Wang                     Tsinghua University  Sophomore   Male    79.0
# Chunqiang Chu                  Fudan University     Junior   Male    72.0
# Mei Xu                         Fudan University  Sophomore   Male    79.0
# Chengpeng Zhou                 Fudan University     Senior   Male    81.0
# ...

# %%
df_demo.loc[df_demo.Grade.isin(['Senior','Freshman'])]
# Out:
#                                        School     Grade  Gender  Weight  \
# Name
# Gaopeng Yang    Shanghai Jiao Tong University  Freshman  Female    46.0
# Changqiang You              Peking University  Freshman    Male    70.0
# Mei Sun         Shanghai Jiao Tong University    Senior    Male    89.0
# Xiaoli Qian               Tsinghua University  Freshman  Female    51.0
# Qiang Chu       Shanghai Jiao Tong University  Freshman  Female    52.0
# ...                                       ...       ...     ...     ...
# Xiaoqiang Qin             Tsinghua University    Senior    Male    79.0
# Yanmei Qian                 Peking University    Senior  Female    49.0
# Li Zhao                   Tsinghua University    Senior  Female    50.0
# Chengqiang Chu  Shanghai Jiao Tong University    Senior  Female    45.0
# Chengmei Shen   Shanghai Jiao Tong University    Senior    Male    71.0
#
#                Transfer
# Name
# Gaopeng Yang          N
# Changqiang You        N
# ...

# %% [markdown]
# iloc 通过位置对行进行操作

# %%
df_demo.iloc[1]
# Out:
# School      Peking University
# Grade                Freshman
# Gender                   Male
# Weight                   70.0
# Transfer                    N
# Name: Changqiang You, dtype: object

# %%
# 使用布尔列表的时候不能直接使用，需要通过values转换为values
df_demo.iloc[(df_demo.Weight>80).values]
# Out:
#                                        School      Grade Gender  Weight  \
# Name
# Mei Sun         Shanghai Jiao Tong University     Senior   Male    89.0
# Qiang Zheng     Shanghai Jiao Tong University     Senior   Male    87.0
# Qiang Han                   Peking University   Freshman   Male    87.0
# Chengpeng Zhou               Fudan University     Senior   Male    81.0
# Feng Han        Shanghai Jiao Tong University  Sophomore   Male    82.0
# Changpeng Zhao              Peking University   Freshman   Male    83.0
# Chunli Zhao     Shanghai Jiao Tong University   Freshman   Male    83.0
# Gaoli Zhao      Shanghai Jiao Tong University     Senior   Male    83.0
#
#                Transfer
# Name
# Mei Sun               N
# Qiang Zheng           N
# Qiang Han             N
# Chengpeng Zhou        N
# Feng Han              N
# Changpeng Zhao        N
# Chunli Zhao           N
# Gaoli Zhao            N

# %%
(df_demo.Weight>80).values
# Out:
# array([False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %% [markdown]
# query方法

# %%
df.query('(School == "Fudan University")&'
         '(Grade == "Senior")')
# Out:
#                School   Grade             Name  Gender  Weight Transfer
# 39   Fudan University  Senior  Chengpeng Zheng  Female    38.0        N
# 46   Fudan University  Senior        Feng Zhou  Female    47.0        N
# 49   Fudan University  Senior        Gaomei Lv  Female    34.0        N
# 52   Fudan University  Senior        Chunli Lv  Female    56.0        N
# 66   Fudan University  Senior   Chengpeng Zhou    Male    81.0        N
# 77   Fudan University  Senior      Gaopeng Qin  Female    52.0        N
# 112  Fudan University  Senior      Chunjuan Xu  Female    47.0        N
# 129  Fudan University  Senior       Juan Zhang  Female    47.0        N
# 131  Fudan University  Senior   Chengpeng Qian    Male    73.0        Y
# 138  Fudan University  Senior    Xiaojuan Qian  Female    50.0        N
# 144  Fudan University  Senior          Quan Xu  Female    44.0        N

# %%
df
# Out:
#                             School      Grade            Name  Gender  Weight  \
# 0    Shanghai Jiao Tong University   Freshman    Gaopeng Yang  Female    46.0
# 1                Peking University   Freshman  Changqiang You    Male    70.0
# 2    Shanghai Jiao Tong University     Senior         Mei Sun    Male    89.0
# 3                 Fudan University  Sophomore    Xiaojuan Sun  Female    41.0
# 4                 Fudan University  Sophomore     Gaojuan You    Male    74.0
# ..                             ...        ...             ...     ...     ...
# 195               Fudan University     Junior    Xiaojuan Sun  Female    46.0
# 196            Tsinghua University     Senior         Li Zhao  Female    50.0
# 197  Shanghai Jiao Tong University     Senior  Chengqiang Chu  Female    45.0
# 198  Shanghai Jiao Tong University     Senior   Chengmei Shen    Male    71.0
# 199            Tsinghua University  Sophomore     Chunpeng Lv    Male    51.0
#
#     Transfer
# 0          N
# ...

# %%
low ,high = 70,80
df.query('Weight.between (@low,@high)')
# Out:
#                             School      Grade              Name Gender  \
# 1                Peking University   Freshman    Changqiang You   Male
# 4                 Fudan University  Sophomore       Gaojuan You   Male
# 10   Shanghai Jiao Tong University   Freshman     Xiaopeng Zhou   Male
# 18             Tsinghua University     Senior      Xiaofeng Sun   Male
# 35               Peking University   Freshman        Gaoli Zhao   Male
# 36               Peking University   Freshman      Xiaojuan Qin   Male
# 40             Tsinghua University  Sophomore           Li Wang   Male
# 41                Fudan University     Junior     Chunqiang Chu   Male
# 48                Fudan University  Sophomore            Mei Xu   Male
# 50   Shanghai Jiao Tong University     Junior       Xiaoli Wang   Male
# 72               Peking University     Junior      Gaoquan Zhou   Male
# 73                Fudan University   Freshman         Feng Wang   Male
# ...

# %% [markdown]
# 随机抽样
# sample  n:抽样数量 axis:方向 frac:抽样比例
# replace:是否放回  weights 每个样本的抽样相对概率

# %%
# 构造一个df
df_sample = pd.DataFrame({'id':list('abcde'),
                          'value':[1,2,3,4,66]})

# %%
df_sample
# Out:
#   id  value
# 0  a      1
# 1  b      2
# 2  c      3
# 3  d      4
# 4  e     66

# %%
df_sample.sample(3,replace=True,weights=df_sample.value)
# Out:
#   id  value
# 4  e     66
# 4  e     66
# 4  e     66

# %%
# loc 支持lambda表达式
df_demo.loc[lambda x:'Quan Zhao',lambda x:'Gender']
# Out:
# 'Female'

# %%
df_demo.loc['Quan Zhao','Gender']
# Out:
# 'Female'

# %%
df_demo.loc['Mei Sun']
# Out:
#                                 School   Grade  Gender  Weight Transfer
# Name
# Mei Sun  Shanghai Jiao Tong University  Senior    Male    89.0        N
# Mei Sun  Shanghai Jiao Tong University  Junior  Female    50.0        N

# %%
df_demo.loc[lambda x:slice('Gaojuan You', 'Gaoqiang Qian')]
# Out:
#                                       School      Grade  Gender  Weight  \
# Name
# Gaojuan You                 Fudan University  Sophomore    Male    74.0
# Xiaoli Qian              Tsinghua University   Freshman  Female    51.0
# Qiang Chu      Shanghai Jiao Tong University   Freshman  Female    52.0
# Gaoqiang Qian            Tsinghua University     Junior  Female    50.0
#
#               Transfer
# Name
# Gaojuan You          N
# Xiaoli Qian          N
# Qiang Chu            N
# Gaoqiang Qian        N

# %%
df_demo.loc['Gaojuan You': 'Gaoqiang Qian']
# Out:
#                                       School      Grade  Gender  Weight  \
# Name
# Gaojuan You                 Fudan University  Sophomore    Male    74.0
# Xiaoli Qian              Tsinghua University   Freshman  Female    51.0
# Qiang Chu      Shanghai Jiao Tong University   Freshman  Female    52.0
# Gaoqiang Qian            Tsinghua University     Junior  Female    50.0
#
#               Transfer
# Name
# Gaojuan You          N
# Xiaoli Qian          N
# Qiang Chu            N
# Gaoqiang Qian        N

# %%
df_demo.loc[lambda x: 'Xiaoli Qian']
# Out:
# School      Tsinghua University
# Grade                  Freshman
# Gender                   Female
# Weight                     51.0
# Transfer                      N
# Name: Xiaoli Qian, dtype: object

# %%
(lambda x:x*2)(5)
# Out:
# 10

# %% [markdown]
# 多级索引
